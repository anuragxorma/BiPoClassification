# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
os.environ['CUDA_VISIBLE_DEVICES'] = "0"

import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
import keras
from keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.utils import to_categorical
import datetime
import gc
import RNN_preprocessing as rp

# %% [markdown]
# RNN

# %%
#Reccurent Neural Network model
def model_rnn (input_shape, output_shape):
    model = keras.Sequential(
        [
            layers.SimpleRNN(64, input_shape=input_shape, activation="tanh", return_sequences=True),
            layers.SimpleRNN(32, activation="tanh"),
            layers.Dense(16, activation="relu"),
            layers.Dense(output_shape, activation="softmax"),
        ]
    )
    model.compile(loss="categorical_crossentropy", optimizer = "adam", metrics=['accuracy'])
    return model

# %%
#Model for the BiPo 214 chain
model1 = model_rnn((rp.seq_length, rp.X1_seq_train.shape[2]), rp.y1_seq_train.shape[1])
model1.summary()
# Out:
# 2024-11-07 14:11:06.551880: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:268] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 10, 64)            4480
#
#  simple_rnn_1 (SimpleRNN)    (None, 32)                3104
#
#  dense (Dense)               (None, 16)                528
#
#  dense_1 (Dense)             (None, 4)                 68
#
# =================================================================
# Total params: 8180 (31.95 KB)
# Trainable params: 8180 (31.95 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Model for the BiPo 212 chain
model2 = model_rnn((rp.seq_length, rp.X2_seq_train.shape[2]), rp.y2_seq_train.shape[1])
model2.summary()
# Out:
# 2024-11-08 13:44:26.462217: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:268] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 10, 64)            4480
#
#  simple_rnn_1 (SimpleRNN)    (None, 32)                3104
#
#  dense (Dense)               (None, 16)                528
#
#  dense_1 (Dense)             (None, 6)                 102
#
# =================================================================
# Total params: 8214 (32.09 KB)
# Trainable params: 8214 (32.09 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#callback for reducing the learning rate and stopping early in case the loss function hits a plateau
callbacks = [
    keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=4, verbose=1, min_lr=1E-6),
    tf.keras.callbacks.EarlyStopping(patience=10, verbose=1, baseline=None, restore_best_weights=True)
]

# %%
# Clear any previous session
tf.keras.backend.clear_session()
gc.collect()
# Out:
# 941

# %%
# Train model 1
history1 = model1.fit(rp.X1_seq_train, rp.y1_seq_train, epochs=200, batch_size=256, verbose=2,
                      validation_data=(rp.X1_seq_val, rp.y1_seq_val),
                      callbacks=callbacks)
# Out:
# Epoch 1/200
# 17288/17288 - 241s - loss: 0.5082 - accuracy: 0.7762 - val_loss: 0.4875 - val_accuracy: 0.7889 - lr: 0.0010 - 241s/epoch - 14ms/step
# Epoch 2/200
# 17288/17288 - 236s - loss: 0.4843 - accuracy: 0.7894 - val_loss: 0.4827 - val_accuracy: 0.7902 - lr: 0.0010 - 236s/epoch - 14ms/step
# Epoch 3/200
# 17288/17288 - 237s - loss: 0.4822 - accuracy: 0.7905 - val_loss: 0.4848 - val_accuracy: 0.7893 - lr: 0.0010 - 237s/epoch - 14ms/step
# Epoch 4/200
# 17288/17288 - 240s - loss: 0.4809 - accuracy: 0.7910 - val_loss: 0.4799 - val_accuracy: 0.7912 - lr: 0.0010 - 240s/epoch - 14ms/step
# Epoch 5/200
# 17288/17288 - 305s - loss: 0.4801 - accuracy: 0.7915 - val_loss: 0.4824 - val_accuracy: 0.7892 - lr: 0.0010 - 305s/epoch - 18ms/step
# Epoch 6/200
# 17288/17288 - 276s - loss: 0.4794 - accuracy: 0.7918 - val_loss: 0.4765 - val_accuracy: 0.7936 - lr: 0.0010 - 276s/epoch - 16ms/step
# Epoch 7/200
# 17288/17288 - 237s - loss: 0.4789 - accuracy: 0.7921 - val_loss: 0.4819 - val_accuracy: 0.7905 - lr: 0.0010 - 237s/epoch - 14ms/step
# Epoch 8/200
# 17288/17288 - 235s - loss: 0.4785 - accuracy: 0.7922 - val_loss: 0.4792 - val_accuracy: 0.7914 - lr: 0.0010 - 235s/epoch - 14ms/step
# Epoch 9/200
# 17288/17288 - 235s - loss: 0.4782 - accuracy: 0.7924 - val_loss: 0.4772 - val_accuracy: 0.7929 - lr: 0.0010 - 235s/epoch - 14ms/step
# Epoch 10/200
- val_loss: 0.4726 - val_accuracy: 0.7949 - lr: 3.1250e-05 - 182s/epoch - 11ms/step
# Epoch 44/200
# 17288/17288 - 182s - loss: 0.4722 - accuracy: 0.7953 - val_loss: 0.4726 - val_accuracy: 0.7949 - lr: 3.1250e-05 - 182s/epoch - 11ms/step
# Epoch 45/200
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 17288/17288 - 182s - loss: 0.4721 - accuracy: 0.7953 - val_loss: 0.4727 - val_accuracy: 0.7948 - lr: 3.1250e-05 - 182s/epoch - 11ms/step
# Epoch 46/200
# 17288/17288 - 182s - loss: 0.4721 - accuracy: 0.7954 - val_loss: 0.4726 - val_accuracy: 0.7949 - lr: 1.5625e-05 - 182s/epoch - 11ms/step
# Epoch 47/200
# 17288/17288 - 182s - loss: 0.4721 - accuracy: 0.7954 - val_loss: 0.4726 - val_accuracy: 0.7949 - lr: 1.5625e-05 - 182s/epoch - 11ms/step
# Epoch 48/200
# 17288/17288 - 182s - loss: 0.4720 - accuracy: 0.7954 - val_loss: 0.4726 - val_accuracy: 0.7949 - lr: 1.5625e-05 - 182s/epoch - 11ms/step
# Epoch 49/200
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 17288/17288 - 182s - loss: 0.4721 - accuracy: 0.7953 - val_loss: 0.4726 - val_accuracy: 0.7949 - lr: 1.5625e-05 - 182s/epoch - 11ms/step
# Epoch 50/200
# 17288/17288 - 182s - loss: 0.4720 - accuracy: 0.7954 - val_loss: 0.4726 - val_accuracy: 0.7949 - lr: 7.8125e-06 - 182s/epoch - 11ms/step
# Epoch 51/200
# 17288/17288 - 182s - loss: 0.4720 - accuracy: 0.7954 - val_loss: 0.4726 - val_accuracy: 0.7949 - lr: 7.8125e-06 - 182s/epoch - 11ms/step
# Epoch 52/200
# 17288/17288 - 182s - loss: 0.4720 - accuracy: 0.7954 - val_loss: 0.4726 - val_accuracy: 0.7949 - lr: 7.8125e-06 - 182s/epoch - 11ms/step
# Epoch 53/200
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 17288/17288 - 182s - loss: 0.4720 - accuracy: 0.7954 - val_loss: 0.4726 - val_accuracy: 0.7949 - lr: 7.8125e-06 - 182s/epoch - 11ms/step
# Epoch 54/200
# 17288/17288 - 182s - loss: 0.4720 - accuracy: 0.7954 - val_loss: 0.4726 - val_accuracy: 0.7949 - lr: 3.9063e-06 - 182s/epoch - 11ms/step
# Epoch 55/200
# 17288/17288 - 182s - loss: 0.4720 - accuracy: 0.7954 - val_loss: 0.4726 - val_accuracy: 0.7949 - lr: 3.9063e-06 - 182s/epoch - 11ms/step
# Epoch 56/200
# 17288/17288 - 182s - loss: 0.4720 - accuracy: 0.7954 - val_loss: 0.4726 - val_accuracy: 0.7949 - lr: 3.9063e-06 - 182s/epoch - 11ms/step
# Epoch 57/200
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 17288/17288 - 182s - loss: 0.4720 - accuracy: 0.7954 - val_loss: 0.4726 - val_accuracy: 0.7950 - lr: 3.9063e-06 - 182s/epoch - 11ms/step
# Epoch 58/200
# 17288/17288 - 182s - loss: 0.4720 - accuracy: 0.7954 - val_loss: 0.4726 - val_accuracy: 0.7949 - lr: 1.9531e-06 - 182s/epoch - 11ms/step
# Epoch 59/200
# 17288/17288 - 182s - loss: 0.4720 - accuracy: 0.7954 - val_loss: 0.4726 - val_accuracy: 0.7950 - lr: 1.9531e-06 - 182s/epoch - 11ms/step
# Epoch 60/200
# 17288/17288 - 182s - loss: 0.4720 - accuracy: 0.7954 - val_loss: 0.4726 - val_accuracy: 0.7949 - lr: 1.9531e-06 - 182s/epoch - 11ms/step
# Epoch 61/200
#
# Epoch 61: ReduceLROnPlateau reducing learning rate to 1e-06.
# 17288/17288 - 182s - loss: 0.4720 - accuracy: 0.7954 - val_loss: 0.4726 - val_accuracy: 0.7949 - lr: 1.9531e-06 - 182s/epoch - 11ms/step
# Epoch 62/200
# 17288/17288 - 182s - loss: 0.4720 - accuracy: 0.7954 - val_loss: 0.4726 - val_accuracy: 0.7949 - lr: 1.0000e-06 - 182s/epoch - 11ms/step
# Epoch 63/200
# 17288/17288 - 182s - loss: 0.4720 - accuracy: 0.7954 - val_loss: 0.4726 - val_accuracy: 0.7950 - lr: 1.0000e-06 - 182s/epoch - 11ms/step
# Epoch 64/200
# 17288/17288 - 182s - loss: 0.4720 - accuracy: 0.7954 - val_loss: 0.4726 - val_accuracy: 0.7949 - lr: 1.0000e-06 - 182s/epoch - 11ms/step
# Epoch 65/200
# 17288/17288 - 182s - loss: 0.4720 - accuracy: 0.7954 - val_loss: 0.4726 - val_accuracy: 0.7949 - lr: 1.0000e-06 - 182s/epoch - 11ms/step
# Epoch 66/200
# 17288/17288 - 182s - loss: 0.4720 - accuracy: 0.7954 - val_loss: 0.4726 - val_accuracy: 0.7949 - lr: 1.0000e-06 - 182s/epoch - 11ms/step
# Epoch 67/200
# 17288/17288 - 182s - loss: 0.4720 - accuracy: 0.7954 - val_loss: 0.4726 - val_accuracy: 0.7949 - lr: 1.0000e-06 - 182s/epoch - 11ms/step
# Epoch 68/200
# 17288/17288 - 182s - loss: 0.4720 - accuracy: 0.7954 - val_loss: 0.4726 - val_accuracy: 0.7949 - lr: 1.0000e-06 - 182s/epoch - 11ms/step
# Epoch 69/200
# Restoring model weights from the end of the best epoch: 59.
# 17288/17288 - 182s - loss: 0.4720 - accuracy: 0.7954 - val_loss: 0.4726 - val_accuracy: 0.7950 - lr: 1.0000e-06 - 182s/epoch - 11ms/step
# Epoch 69: early stopping

# %%
#plotting the accuracy of the first model
import matplotlib.pyplot as plt
plt.plot(history1.history['accuracy'], label='accuracy')
plt.plot(history1.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
#plotting the loss over epoch for the first model
plt.plot(history1.history['loss'], label='loss')
plt.plot(history1.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
# Generate sequences of the test data of the first chain
X1_test_seq, y1_test_seq = rp.create_sequences(rp.fes.X1_test, rp.fes.y1_test, rp.seq_length)

# Predict the labels for the test set
y_pred1 = model1.predict(X1_test_seq)

#convert predictions to class labels
y_pred_classes1 = np.argmax(y_pred1, axis=1)

# Convert one-hot encoded true labels back to class labels
y_test_classes1 = np.argmax(y1_test_seq, axis=1)
# Out:
# 54025/54025 [==============================] - 138s 3ms/step

# %%
#plotting confusion matrix for the first model
import seaborn as sns
from sklearn.metrics import confusion_matrix

conf_matrix1 = confusion_matrix(y_test_classes1, y_pred_classes1)
sns.heatmap(conf_matrix1, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import pandas as pd

# Calculate metrics
precision_macro = precision_score(y_test_classes1, y_pred_classes1, average='macro')
recall_macro = recall_score(y_test_classes1, y_pred_classes1, average='macro')
f1_macro = f1_score(y_test_classes1, y_pred_classes1, average='macro')

precision_micro = precision_score(y_test_classes1, y_pred_classes1, average='micro')
recall_micro = recall_score(y_test_classes1, y_pred_classes1, average='micro')
f1_micro = f1_score(y_test_classes1, y_pred_classes1, average='micro')

precision_weighted = precision_score(y_test_classes1, y_pred_classes1, average='weighted')
recall_weighted = recall_score(y_test_classes1, y_pred_classes1, average='weighted')
f1_weighted = f1_score(y_test_classes1, y_pred_classes1, average='weighted')

# Create a summary table for F1, Recall, and Precision
metrics_summary = pd.DataFrame({
    'Metric': [
        'Precision (Macro)', 'Recall (Macro)', 'F1 Score (Macro)',
        'Precision (Micro)', 'Recall (Micro)', 'F1 Score (Micro)',
        'Precision (Weighted)', 'Recall (Weighted)', 'F1 Score (Weighted)'
    ],
    'Score': [
        precision_macro, recall_macro, f1_macro,
        precision_micro, recall_micro, f1_micro,
        precision_weighted, recall_weighted, f1_weighted
    ]
})

# Display the table
print(metrics_summary)
# Out:
#                  Metric     Score
# 0     Precision (Macro)  0.812861
# 1        Recall (Macro)  0.794584
# 2      F1 Score (Macro)  0.794740
# 3     Precision (Micro)  0.794708
# 4        Recall (Micro)  0.794708
# 5      F1 Score (Micro)  0.794708
# 6  Precision (Weighted)  0.812967
# 7     Recall (Weighted)  0.794708
# 8   F1 Score (Weighted)  0.794873

# %%
#save the first trained model
model1.save('model_SimpleRNN_214.h5')
# Out:
# /home/pipc06/.local/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Train model 2
history2 = model2.fit(rp.X2_seq_train, rp.y2_seq_train, epochs=200, batch_size=256, verbose=2,
                      validation_data=(rp.X2_seq_val, rp.y2_seq_val),
                      callbacks=callbacks)
# Out:
# Epoch 1/200
# 16039/16039 - 240s - loss: 0.4720 - accuracy: 0.7960 - val_loss: 0.4442 - val_accuracy: 0.8104 - lr: 0.0010 - 240s/epoch - 15ms/step
# Epoch 2/200
# 16039/16039 - 233s - loss: 0.4455 - accuracy: 0.8101 - val_loss: 0.4434 - val_accuracy: 0.8111 - lr: 0.0010 - 233s/epoch - 15ms/step
# Epoch 3/200
# 16039/16039 - 231s - loss: 0.4440 - accuracy: 0.8109 - val_loss: 0.4417 - val_accuracy: 0.8114 - lr: 0.0010 - 231s/epoch - 14ms/step
# Epoch 4/200
# 16039/16039 - 229s - loss: 0.4427 - accuracy: 0.8115 - val_loss: 0.4435 - val_accuracy: 0.8104 - lr: 0.0010 - 229s/epoch - 14ms/step
# Epoch 5/200
# 16039/16039 - 229s - loss: 0.4419 - accuracy: 0.8120 - val_loss: 0.4384 - val_accuracy: 0.8140 - lr: 0.0010 - 229s/epoch - 14ms/step
# Epoch 6/200
# 16039/16039 - 229s - loss: 0.4415 - accuracy: 0.8122 - val_loss: 0.4461 - val_accuracy: 0.8097 - lr: 0.0010 - 229s/epoch - 14ms/step
# Epoch 7/200
# 16039/16039 - 209s - loss: 0.4411 - accuracy: 0.8125 - val_loss: 0.4406 - val_accuracy: 0.8126 - lr: 0.0010 - 209s/epoch - 13ms/step
# Epoch 8/200
# 16039/16039 - 175s - loss: 0.4407 - accuracy: 0.8126 - val_loss: 0.4434 - val_accuracy: 0.8115 - lr: 0.0010 - 175s/epoch - 11ms/step
# Epoch 9/200
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 16039/16039 - 175s - loss: 0.4404 - accuracy: 0.8128 - val_loss: 0.4413 - val_accuracy: 0.8131 - lr: 0.0010 - 175s/epoch - 11ms/step
# Epoch 10/200
# 16039/16039 - 175s - loss: 0.4376 - accuracy: 0.8143 - val_loss: 0.4360 - val_accuracy: 0.8154 - lr: 5.0000e-04 - 175s/epoch - 11ms/step
# Epoch 11/200
# 16039/16039 - 175s - loss: 0.4376 - accuracy: 0.8144 - val_loss: 0.4365 - val_accuracy: 0.8151 - lr: 5.0000e-04 - 175s/epoch - 11ms/step
# Epoch 12/200
# 16039/16039 - 175s - loss: 0.4375 - accuracy: 0.8144 - val_loss: 0.4358 - val_accuracy: 0.8155 - lr: 5.0000e-04 - 175s/epoch - 11ms/step
# Epoch 13/200
# 16039/16039 - 175s - loss: 0.4374 - accuracy: 0.8144 - val_loss: 0.4376 - val_accuracy: 0.8145 - lr: 5.0000e-04 - 175s/epoch - 11ms/step
# Epoch 14/200
# 16039/16039 - 175s - loss: 0.4373 - accuracy: 0.8145 - val_loss: 0.4375 - val_accuracy: 0.8145 - lr: 5.0000e-04 - 175s/epoch - 11ms/step
# Epoch 15/200
# 16039/16039 - 175s - loss: 0.4372 - accuracy: 0.8144 - val_loss: 0.4362 - val_accuracy: 0.8154 - lr: 5.0000e-04 - 175s/epoch - 11ms/step
# Epoch 16/200
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 16039/16039 - 175s - loss: 0.4372 - accuracy: 0.8146 - val_loss: 0.4383 - val_accuracy: 0.8134 - lr: 5.0000e-04 - 175s/epoch - 11ms/step
# Epoch 17/200
# 16039/16039 - 175s - loss: 0.4359 - accuracy: 0.8151 - val_loss: 0.4353 - val_accuracy: 0.8156 - lr: 2.5000e-04 - 175s/epoch - 11ms/step
# Epoch 18/200
# 16039/16039 - 175s - loss: 0.4359 - accuracy: 0.8153 - val_loss: 0.4354 - val_accuracy: 0.8156 - lr: 2.5000e-04 - 175s/epoch - 11ms/step
# Epoch 19/200
# 16039/16039 - 175s - loss: 0.4358 - accuracy: 0.8152 - val_loss: 0.4350 - val_accuracy: 0.8159 - lr: 2.5000e-04 - 175s/epoch - 11ms/step
# Epoch 20/200
# 16039/16039 - 175s - loss: 0.4358 - accuracy: 0.8153 - val_loss: 0.4349 - val_accuracy: 0.8160 - lr: 2.5000e-04 - 175s/epoch - 11ms/step
# Epoch 21/200
# 16039/16039 - 175s - loss: 0.4358 - accuracy: 0.8153 - val_loss: 0.4364 - val_accuracy: 0.8150 - lr: 2.5000e-04 - 175s/epoch - 11ms/step
# Epoch 22/200
# 16039/16039 - 175s - loss: 0.4357 - accuracy: 0.8152 - val_loss: 0.4351 - val_accuracy: 0.8158 - lr: 2.5000e-04 - 175s/epoch - 11ms/step
# Epoch 23/200
# 16039/16039 - 175s - loss: 0.4358 - accuracy: 0.8153 - val_loss: 0.4365 - val_accuracy: 0.8151 - lr: 2.5000e-04 - 175s/epoch - 11ms/step
# Epoch 24/200
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 16039/16039 - 175s - loss: 0.4357 - accuracy: 0.8152 - val_loss: 0.4348 - val_accuracy: 0.8160 - lr: 2.5000e-04 - 175s/epoch - 11ms/step
# Epoch 25/200
# 16039/16039 - 175s - loss: 0.4351 - accuracy: 0.8157 - val_loss: 0.4347 - val_accuracy: 0.8159 - lr: 1.2500e-04 - 175s/epoch - 11ms/step
# Epoch 26/200
# 16039/16039 - 175s - loss: 0.4350 - accuracy: 0.8157 - val_loss: 0.4345 - val_accuracy: 0.8161 - lr: 1.2500e-04 - 175s/epoch - 11ms/step
# Epoch 27/200
# 16039/16039 - 175s - loss: 0.4350 - accuracy: 0.8157 - val_loss: 0.4347 - val_accuracy: 0.8159 - lr: 1.2500e-04 - 175s/epoch - 11ms/step
# Epoch 28/200
# 16039/16039 - 175s - loss: 0.4350 - accuracy: 0.8156 - val_loss: 0.4345 - val_accuracy: 0.8161 - lr: 1.2500e-04 - 175s/epoch - 11ms/step
# Epoch 29/200
# 16039/16039 - 175s - loss: 0.4350 - accuracy: 0.8157 - val_loss: 0.4345 - val_accuracy: 0.8162 - lr: 1.2500e-04 - 175s/epoch - 11ms/step
# Epoch 30/200
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 16039/16039 - 175s - loss: 0.4350 - accuracy: 0.8157 - val_loss: 0.4348 - val_accuracy: 0.8160 - lr: 1.2500e-04 - 175s/epoch - 11ms/step
# Epoch 31/200
# 16039/16039 - 175s - loss: 0.4346 - accuracy: 0.8159 - val_loss: 0.4344 - val_accuracy: 0.8162 - lr: 6.2500e-05 - 175s/epoch - 11ms/step
# Epoch 32/200
# 16039/16039 - 175s - loss: 0.4346 - accuracy: 0.8159 - val_loss: 0.4344 - val_accuracy: 0.8162 - lr: 6.2500e-05 - 175s/epoch - 11ms/step
# Epoch 33/200
# 16039/16039 - 175s - loss: 0.4346 - accuracy: 0.8158 - val_loss: 0.4343 - val_accuracy: 0.8163 - lr: 6.2500e-05 - 175s/epoch - 11ms/step
# Epoch 34/200
# 16039/16039 - 175s - loss: 0.4346 - accuracy: 0.8159 - val_loss: 0.4344 - val_accuracy: 0.8161 - lr: 6.2500e-05 - 175s/epoch - 11ms/step
# Epoch 35/200
# 16039/16039 - 175s - loss: 0.4346 - accuracy: 0.8159 - val_loss: 0.4344 - val_accuracy: 0.8161 - lr: 6.2500e-05 - 175s/epoch - 11ms/step
# Epoch 36/200
# 16039/16039 - 175s - loss: 0.4346 - accuracy: 0.8159 - val_loss: 0.4346 - val_accuracy: 0.8161 - lr: 6.2500e-05 - 175s/epoch - 11ms/step
# Epoch 37/200
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 16039/16039 - 175s - loss: 0.4346 - accuracy: 0.8159 - val_loss: 0.4344 - val_accuracy: 0.8161 - lr: 6.2500e-05 - 175s/epoch - 11ms/step
# Epoch 38/200
# 16039/16039 - 176s - loss: 0.4344 - accuracy: 0.8160 - val_loss: 0.4344 - val_accuracy: 0.8161 - lr: 3.1250e-05 - 176s/epoch - 11ms/step
# Epoch 39/200
# 16039/16039 - 176s - loss: 0.4344 - accuracy: 0.8160 - val_loss: 0.4345 - val_accuracy: 0.8161 - lr: 3.1250e-05 - 176s/epoch - 11ms/step
# Epoch 40/200
# 16039/16039 - 175s - loss: 0.4344 - accuracy: 0.8160 - val_loss: 0.4343 - val_accuracy: 0.8163 - lr: 3.1250e-05 - 175s/epoch - 11ms/step
# Epoch 41/200
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 16039/16039 - 175s - loss: 0.4344 - accuracy: 0.8160 - val_loss: 0.4343 - val_accuracy: 0.8162 - lr: 3.1250e-05 - 175s/epoch - 11ms/step
# Epoch 42/200
# 16039/16039 - 175s - loss: 0.4343 - accuracy: 0.8161 - val_loss: 0.4343 - val_accuracy: 0.8163 - lr: 1.5625e-05 - 175s/epoch - 11ms/step
# Epoch 43/200
# 16039/16039 - 175s - loss: 0.4343 - accuracy: 0.8161 - val_loss: 0.4342 - val_accuracy: 0.8163 - lr: 1.5625e-05 - 175s/epoch - 11ms/step
# Epoch 44/200
# 16039/16039 - 175s - loss: 0.4343 - accuracy: 0.8160 - val_loss: 0.4342 - val_accuracy: 0.8163 - lr: 1.5625e-05 - 175s/epoch - 11ms/step
# Epoch 45/200
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 16039/16039 - 175s - loss: 0.4343 - accuracy: 0.8161 - val_loss: 0.4342 - val_accuracy: 0.8163 - lr: 1.5625e-05 - 175s/epoch - 11ms/step
# Epoch 46/200
# 16039/16039 - 175s - loss: 0.4342 - accuracy: 0.8161 - val_loss: 0.4342 - val_accuracy: 0.8163 - lr: 7.8125e-06 - 175s/epoch - 11ms/step
# Epoch 47/200
# 16039/16039 - 175s - loss: 0.4342 - accuracy: 0.8161 - val_loss: 0.4342 - val_accuracy: 0.8163 - lr: 7.8125e-06 - 175s/epoch - 11ms/step
# Epoch 48/200
# 16039/16039 - 175s - loss: 0.4342 - accuracy: 0.8161 - val_loss: 0.4342 - val_accuracy: 0.8163 - lr: 7.8125e-06 - 175s/epoch - 11ms/step
# Epoch 49/200
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 16039/16039 - 175s - loss: 0.4342 - accuracy: 0.8161 - val_loss: 0.4342 - val_accuracy: 0.8163 - lr: 7.8125e-06 - 175s/epoch - 11ms/step
# Epoch 50/200
# 16039/16039 - 175s - loss: 0.4342 - accuracy: 0.8161 - val_loss: 0.4342 - val_accuracy: 0.8163 - lr: 3.9063e-06 - 175s/epoch - 11ms/step
# Epoch 51/200
# 16039/16039 - 175s - loss: 0.4342 - accuracy: 0.8162 - val_loss: 0.4342 - val_accuracy: 0.8163 - lr: 3.9063e-06 - 175s/epoch - 11ms/step
# Epoch 52/200
# 16039/16039 - 175s - loss: 0.4342 - accuracy: 0.8161 - val_loss: 0.4342 - val_accuracy: 0.8163 - lr: 3.9063e-06 - 175s/epoch - 11ms/step
# Epoch 53/200
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 16039/16039 - 175s - loss: 0.4342 - accuracy: 0.8161 - val_loss: 0.4342 - val_accuracy: 0.8163 - lr: 3.9063e-06 - 175s/epoch - 11ms/step
# Epoch 54/200
# 16039/16039 - 175s - loss: 0.4342 - accuracy: 0.8161 - val_loss: 0.4342 - val_accuracy: 0.8163 - lr: 1.9531e-06 - 175s/epoch - 11ms/step
# Epoch 55/200
# Restoring model weights from the end of the best epoch: 45.
# 16039/16039 - 175s - loss: 0.4342 - accuracy: 0.8162 - val_loss: 0.4342 - val_accuracy: 0.8163 - lr: 1.9531e-06 - 175s/epoch - 11ms/step
# Epoch 55: early stopping

# %%
#plotting the accuracy of the second model
import matplotlib.pyplot as plt
plt.plot(history2.history['accuracy'], label='accuracy')
plt.plot(history2.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
#plotting the loss over epoch for the second model
plt.plot(history2.history['loss'], label='loss')
plt.plot(history2.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
# Generate sequences of the test data of the second chain
X2_test_seq, y2_test_seq = rp.create_sequences(rp.fes.X2_test, rp.fes.y2_test, rp.seq_length)
# Predict the labels for the test set
y_pred2 = model2.predict(X2_test_seq)

#convert predictions to class labels
y_pred_classes2 = np.argmax(y_pred2, axis=1)

# Convert one-hot encoded true labels back to class labels
y_test_classes2 = np.argmax(y2_test_seq, axis=1)
# Out:
# 53464/53464 [==============================] - 343s 6ms/step

# %%
#plotting confusion matrix for the second model
import seaborn as sns
from sklearn.metrics import confusion_matrix
conf_matrix2 = confusion_matrix(y_test_classes2, y_pred_classes2)
sns.heatmap(conf_matrix2, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import pandas as pd

# Calculate metrics
precision_macro = precision_score(y_test_classes2, y_pred_classes2, average='macro')
recall_macro = recall_score(y_test_classes2, y_pred_classes2, average='macro')
f1_macro = f1_score(y_test_classes2, y_pred_classes2, average='macro')

precision_micro = precision_score(y_test_classes2, y_pred_classes2, average='micro')
recall_micro = recall_score(y_test_classes2, y_pred_classes2, average='micro')
f1_micro = f1_score(y_test_classes2, y_pred_classes2, average='micro')

precision_weighted = precision_score(y_test_classes2, y_pred_classes2, average='weighted')
recall_weighted = recall_score(y_test_classes2, y_pred_classes2, average='weighted')
f1_weighted = f1_score(y_test_classes2, y_pred_classes2, average='weighted')

# Create a summary table for F1, Recall, and Precision
metrics_summary = pd.DataFrame({
    'Metric': [
        'Precision (Macro)', 'Recall (Macro)', 'F1 Score (Macro)',
        'Precision (Micro)', 'Recall (Micro)', 'F1 Score (Micro)',
        'Precision (Weighted)', 'Recall (Weighted)', 'F1 Score (Weighted)'
    ],
    'Score': [
        precision_macro, recall_macro, f1_macro,
        precision_micro, recall_micro, f1_micro,
        precision_weighted, recall_weighted, f1_weighted
    ]
})

# Display the table
print(metrics_summary)
# Out:
#                  Metric     Score
# 0     Precision (Macro)  0.834127
# 1        Recall (Macro)  0.815755
# 2      F1 Score (Macro)  0.817826
# 3     Precision (Micro)  0.815310
# 4        Recall (Micro)  0.815310
# 5      F1 Score (Micro)  0.815310
# 6  Precision (Weighted)  0.833941
# 7     Recall (Weighted)  0.815310
# 8   F1 Score (Weighted)  0.817444

# %%
#save the second trained model
model2.save('model_SimpleRNN_212.h5')
# Out:
# /home/pipc06/.local/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
