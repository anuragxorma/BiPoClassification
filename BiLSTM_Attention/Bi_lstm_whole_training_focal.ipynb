# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
os.environ['CUDA_VISIBLE_DEVICES'] = "0"

import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
import keras
from keras import layers
from tensorflow.keras.layers import Layer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, LSTM, Bidirectional, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from keras.losses import CategoricalFocalCrossentropy
import gc
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import pandas as pd

# %%
import sys
sys.path.append('../data_preprocessing')

# %%
import RNN_preprocessing_whole as rp

# %%
X_seq_train = rp.X_seq_train
X_seq_test = rp.X_seq_test
y_seq_train = rp.y_seq_train
y_seq_test = rp.y_seq_test

# %%
# Clear memory associated with the module
import sys
del rp
if 'RNN_preprocessing_whole' in sys.modules:
    del sys.modules['RNN_preprocessing_whole']

# Clear memory from global variables if needed
import gc
gc.collect()
# Out:
# 5

# %%
X_seq_train, X_seq_val, y_seq_train, y_seq_val = train_test_split(X_seq_train, y_seq_train, test_size=0.2, random_state=0)

# %%
X_train = X_seq_train
X_val = X_seq_val
y_train = y_seq_train
y_val = y_seq_val

# %%
# Delete the training/test split variables after they are used
del X_seq_train, X_seq_val, y_seq_train, y_seq_val

# Force garbage collection
gc.collect()
# Out:
# 0

# %% [markdown]
# LSTM

# %%
class Attention(Layer):
    def __init__(self, **kwargs):
        super(Attention, self).__init__(**kwargs)

    def call(self, inputs):
        """
        Applies attention mechanism to the inputs.

        Args:
            inputs: Tensor of shape (batch_size, seq_length, features).

        Returns:
            Tensor of shape (batch_size, features).
        """
        query = inputs  # Use the same input as query, key, and value
        key = inputs
        value = inputs

        # Compute attention scores
        scores = tf.matmul(query, key, transpose_b=True)  # Shape: (batch, seq_length, seq_length)
        scores = tf.nn.softmax(scores, axis=-1)  # Normalize scores

        # Weighted sum of the values
        context = tf.matmul(scores, value)  # Shape: (batch, seq_length, features)

        return context

# %%
def build_bilstm_with_attention(input_shape, num_classes):
    """
    Builds a BiLSTM model with an attention mechanism.

    Args:
        input_shape (tuple): Shape of the input data (seq_length, num_features).
        num_classes (int): Number of output classes.

    Returns:
        keras.Model: Compiled BiLSTM model with attention.
    """
    inputs = Input(shape=input_shape)
    x = Bidirectional(LSTM(64, return_sequences=True))(inputs)
    x = Attention()(x)  # Add attention mechanism
    x = TimeDistributed(Dense(64, activation="relu"))(x)
    outputs = Dense(num_classes, activation="softmax")(x)

    model = Model(inputs, outputs)

    # 👇 Here's the only change
    model.compile(
        optimizer="adam",
        loss=CategoricalFocalCrossentropy(gamma=2.0),
        metrics=["accuracy"]
    )

    return model

# %%
seq_length = 10

# %%
#Model 
model = build_bilstm_with_attention((seq_length, X_train.shape[2]), y_train.shape[2])

model.summary()
# Out:
# 2025-07-24 10:54:06.743896: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:268] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 10, 6)]           0
#
#  bidirectional (Bidirection  (None, 10, 128)           36352
#  al)
#
#  attention (Attention)       (None, 10, 128)           0
#
#  time_distributed (TimeDist  (None, 10, 64)            8256
#  ributed)
#
#  dense_1 (Dense)             (None, 10, 6)             390
#
# =================================================================
# Total params: 44998 (175.77 KB)
# Trainable params: 44998 (175.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#callback for reducing the learning rate and stopping early in case the loss function hits a plateau
callbacks = [
    keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=4, verbose=1, min_lr=1E-6),
    tf.keras.callbacks.EarlyStopping(patience=10, verbose=1, baseline=None, restore_best_weights=True)
]

# %%
# Clear any previous session
tf.keras.backend.clear_session()
gc.collect()
# Out:
# 6184

# %%
history = model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=256,
    verbose=2,
    validation_data=(X_val, y_val),
    callbacks=callbacks
)
# Out:
# Epoch 1/200
# 16851/16851 - 905s - loss: 0.0074 - accuracy: 0.9785 - val_loss: 0.0058 - val_accuracy: 0.9821 - lr: 0.0010 - 905s/epoch - 54ms/step
# Epoch 2/200
# 16851/16851 - 679s - loss: 0.0057 - accuracy: 0.9821 - val_loss: 0.0056 - val_accuracy: 0.9823 - lr: 0.0010 - 679s/epoch - 40ms/step
# Epoch 3/200
# 16851/16851 - 830s - loss: 0.0055 - accuracy: 0.9823 - val_loss: 0.0055 - val_accuracy: 0.9824 - lr: 0.0010 - 830s/epoch - 49ms/step
# Epoch 4/200
# 16851/16851 - 728s - loss: 0.0055 - accuracy: 0.9824 - val_loss: 0.0055 - val_accuracy: 0.9824 - lr: 0.0010 - 728s/epoch - 43ms/step
# Epoch 5/200
# 16851/16851 - 647s - loss: 0.0054 - accuracy: 0.9824 - val_loss: 0.0055 - val_accuracy: 0.9820 - lr: 0.0010 - 647s/epoch - 38ms/step
# Epoch 6/200
# 16851/16851 - 640s - loss: 0.0054 - accuracy: 0.9825 - val_loss: 0.0054 - val_accuracy: 0.9826 - lr: 0.0010 - 640s/epoch - 38ms/step
# Epoch 7/200
# 16851/16851 - 848s - loss: 0.0054 - accuracy: 0.9825 - val_loss: 0.0054 - val_accuracy: 0.9826 - lr: 0.0010 - 848s/epoch - 50ms/step
# Epoch 8/200
# 16851/16851 - 707s - loss: 0.0054 - accuracy: 0.9826 - val_loss: 0.0053 - val_accuracy: 0.9827 - lr: 0.0010 - 707s/epoch - 42ms/step
# Epoch 9/200
# 16851/16851 - 640s - loss: 0.0054 - accuracy: 0.9826 - val_loss: 0.0053 - val_accuracy: 0.9827 - lr: 0.0010 - 640s/epoch - 38ms/step
# Epoch 10/200
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 16851/16851 - 640s - loss: 0.0054 - accuracy: 0.9826 - val_loss: 0.0053 - val_accuracy: 0.9827 - lr: 0.0010 - 640s/epoch - 38ms/step
# Epoch 11/200
# 16851/16851 - 640s - loss: 0.0053 - accuracy: 0.9828 - val_loss: 0.0053 - val_accuracy: 0.9827 - lr: 5.0000e-04 - 640s/epoch - 38ms/step
# Epoch 12/200
# 16851/16851 - 640s - loss: 0.0053 - accuracy: 0.9828 - val_loss: 0.0053 - val_accuracy: 0.9828 - lr: 5.0000e-04 - 640s/epoch - 38ms/step
# Epoch 13/200
# 16851/16851 - 640s - loss: 0.0053 - accuracy: 0.9828 - val_loss: 0.0053 - val_accuracy: 0.9828 - lr: 5.0000e-04 - 640s/epoch - 38ms/step
# Epoch 14/200
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 16851/16851 - 640s - loss: 0.0053 - accuracy: 0.9828 - val_loss: 0.0053 - val_accuracy: 0.9827 - lr: 5.0000e-04 - 640s/epoch - 38ms/step
# Epoch 15/200
# 16851/16851 - 640s - loss: 0.0053 - accuracy: 0.9829 - val_loss: 0.0052 - val_accuracy: 0.9830 - lr: 2.5000e-04 - 640s/epoch - 38ms/step
# Epoch 16/200
# 16851/16851 - 640s - loss: 0.0053 - accuracy: 0.9829 - val_loss: 0.0052 - val_accuracy: 0.9830 - lr: 2.5000e-04 - 640s/epoch - 38ms/step
# Epoch 17/200
# 16851/16851 - 640s - loss: 0.0052 - accuracy: 0.9830 - val_loss: 0.0053 - val_accuracy: 0.9829 - lr: 2.5000e-04 - 640s/epoch - 38ms/step
# Epoch 18/200
# 16851/16851 - 640s - loss: 0.0052 - accuracy: 0.9830 - val_loss: 0.0052 - val_accuracy: 0.9830 - lr: 2.5000e-04 - 640s/epoch - 38ms/step
# Epoch 19/200
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 16851/16851 - 640s - loss: 0.0052 - accuracy: 0.9830 - val_loss: 0.0053 - val_accuracy: 0.9830 - lr: 2.5000e-04 - 640s/epoch - 38ms/step
# Epoch 20/200
# 16851/16851 - 640s - loss: 0.0052 - accuracy: 0.9830 - val_loss: 0.0052 - val_accuracy: 0.9830 - lr: 1.2500e-04 - 640s/epoch - 38ms/step
# Epoch 21/200
# 16851/16851 - 788s - loss: 0.0052 - accuracy: 0.9830 - val_loss: 0.0052 - val_accuracy: 0.9830 - lr: 1.2500e-04 - 788s/epoch - 47ms/step
# Epoch 22/200
# 16851/16851 - 775s - loss: 0.0052 - accuracy: 0.9830 - val_loss: 0.0052 - val_accuracy: 0.9830 - lr: 1.2500e-04 - 775s/epoch - 46ms/step
# Epoch 23/200
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 16851/16851 - 641s - loss: 0.0052 - accuracy: 0.9830 - val_loss: 0.0052 - val_accuracy: 0.9830 - lr: 1.2500e-04 - 641s/epoch - 38ms/step
# Epoch 24/200
# 16851/16851 - 641s - loss: 0.0052 - accuracy: 0.9830 - val_loss: 0.0052 - val_accuracy: 0.9830 - lr: 6.2500e-05 - 641s/epoch - 38ms/step
# Epoch 25/200
# 16851/16851 - 640s - loss: 0.0052 - accuracy: 0.9830 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 6.2500e-05 - 640s/epoch - 38ms/step
# Epoch 26/200
# 16851/16851 - 641s - loss: 0.0052 - accuracy: 0.9830 - val_loss: 0.0052 - val_accuracy: 0.9830 - lr: 6.2500e-05 - 641s/epoch - 38ms/step
# Epoch 27/200
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 16851/16851 - 761s - loss: 0.0052 - accuracy: 0.9830 - val_loss: 0.0052 - val_accuracy: 0.9830 - lr: 6.2500e-05 - 761s/epoch - 45ms/step
# Epoch 28/200
# 16851/16851 - 794s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9830 - lr: 3.1250e-05 - 794s/epoch - 47ms/step
# Epoch 29/200
# 16851/16851 - 641s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9830 - lr: 3.1250e-05 - 641s/epoch - 38ms/step
# Epoch 30/200
# 16851/16851 - 640s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 3.1250e-05 - 640s/epoch - 38ms/step
# Epoch 31/200
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 16851/16851 - 640s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 3.1250e-05 - 640s/epoch - 38ms/step
# Epoch 32/200
# 16851/16851 - 641s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9830 - lr: 1.5625e-05 - 641s/epoch - 38ms/step
# Epoch 33/200
# 16851/16851 - 640s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 1.5625e-05 - 640s/epoch - 38ms/step
# Epoch 34/200
# 16851/16851 - 669s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 1.5625e-05 - 669s/epoch - 40ms/step
# Epoch 35/200
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 16851/16851 - 641s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 1.5625e-05 - 641s/epoch - 38ms/step
# Epoch 36/200
# 16851/16851 - 641s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 7.8125e-06 - 641s/epoch - 38ms/step
# Epoch 37/200
# 16851/16851 - 641s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 7.8125e-06 - 641s/epoch - 38ms/step
# Epoch 38/200
# 16851/16851 - 640s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 7.8125e-06 - 640s/epoch - 38ms/step
# Epoch 39/200
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 16851/16851 - 641s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 7.8125e-06 - 641s/epoch - 38ms/step
# Epoch 40/200
# 16851/16851 - 641s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 3.9063e-06 - 641s/epoch - 38ms/step
# Epoch 41/200
# 16851/16851 - 641s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 3.9063e-06 - 641s/epoch - 38ms/step
# Epoch 42/200
# 16851/16851 - 641s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 3.9063e-06 - 641s/epoch - 38ms/step
# Epoch 43/200
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 16851/16851 - 641s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 3.9063e-06 - 641s/epoch - 38ms/step
# Epoch 44/200
# 16851/16851 - 640s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 1.9531e-06 - 640s/epoch - 38ms/step
# Epoch 45/200
# 16851/16851 - 640s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 1.9531e-06 - 640s/epoch - 38ms/step
# Epoch 46/200
# 16851/16851 - 640s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 1.9531e-06 - 640s/epoch - 38ms/step
# Epoch 47/200
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1e-06.
# 16851/16851 - 640s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 1.9531e-06 - 640s/epoch - 38ms/step
# Epoch 48/200
# 16851/16851 - 641s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 1.0000e-06 - 641s/epoch - 38ms/step
# Epoch 49/200
# 16851/16851 - 641s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 1.0000e-06 - 641s/epoch - 38ms/step
# Epoch 50/200
# 16851/16851 - 640s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 1.0000e-06 - 640s/epoch - 38ms/step
# Epoch 51/200
# 16851/16851 - 640s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 1.0000e-06 - 640s/epoch - 38ms/step
# Epoch 52/200
# 16851/16851 - 641s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 1.0000e-06 - 641s/epoch - 38ms/step
# Epoch 53/200
# 16851/16851 - 641s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 1.0000e-06 - 641s/epoch - 38ms/step
# Epoch 54/200
# Restoring model weights from the end of the best epoch: 44.
# 16851/16851 - 640s - loss: 0.0052 - accuracy: 0.9831 - val_loss: 0.0052 - val_accuracy: 0.9831 - lr: 1.0000e-06 - 640s/epoch - 38ms/step
# Epoch 54: early stopping

# %%
#plotting the accuracy of the first model
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
#plotting the loss over epoch for the first model
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
#save the first trained model
model.save('../models/model_bidirec_lstm_whole_focal.h5')
# Out:
# /home/pipc06/.local/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
