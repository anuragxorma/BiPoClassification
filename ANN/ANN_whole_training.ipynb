# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import joblib

# %%
import sys
sys.path.append('../data_preprocessing')

# %%
import feature_engineering_scaling as fes

# %%
# One-hot encode the target variable
y_cat = to_categorical(fes.y)

# %%
X = fes.X_scaled

# %%
scaler = MinMaxScaler()
X.loc[:, 'time'] = scaler.fit_transform(X[['time']])  # Normalize safely

# %%
# Save scaler for inverse transformation later
joblib.dump(scaler, '../scalers/time_scaler.pkl')
# Out:
# ['../scalers/time_scaler.pkl']

# %%
X.head()
# Out:
#      energy         r         z       phi      time
# 0  0.000350  0.001903  0.002125  0.982794  0.000000
# 1  0.277952  0.702870  0.820725 -2.270700  0.001030
# 2  0.017027  0.769946 -0.602846  2.305639  0.001030
# 3  0.117614  0.849347  0.578648  1.856658  0.001031
# 4  0.723605  0.180800  0.423572  3.138980  0.001031

# %%
# Further split using train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y_cat, test_size=0.2, random_state=0)

# %%
# Further split using train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# %% [markdown]
# # Simple ANN

# %%
#Simple MLP
def simple_model_ann (input_shape, output_shape):
    model= keras.Sequential(
        [
            keras.Input(shape=input_shape),
            layers.Flatten(),
            layers.Dense (256, activation = "relu"),
            layers.Dense (256, activation = "relu"),
            layers.Dense (output_shape, activation = "softmax"),
        
        ]
    )
    model.compile (loss="categorical_crossentropy", optimizer = "adam", metrics=['accuracy'])
    
    return model

# %%
#For the first radioactive chain i.e. BiPo 214
model = simple_model_ann(X_train.shape[1], y_train.shape[1])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 5)                 0
#
#  dense (Dense)               (None, 256)               1536
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dense_2 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 69898 (273.04 KB)
# Trainable params: 69898 (273.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 2025-03-10 14:48:23.414702: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:268] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
#Callback to decrease the learning rate and to stop early in case the loss hits a plateau
callbacks=[
    keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=4, verbose=1, min_lr=1E-6),
     keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
]

# %%
# Train the first model
history = model.fit(X_train, y_train, epochs=200, batch_size=10000, verbose=2,
                      validation_data=(X_val, y_val),
                      callbacks=callbacks)
# Out:
# Epoch 1/200
# 413/413 - 56s - loss: 1.2670 - accuracy: 0.5212 - val_loss: 1.0895 - val_accuracy: 0.6061 - lr: 0.0010 - 56s/epoch - 136ms/step
# Epoch 2/200
# 413/413 - 47s - loss: 0.9493 - accuracy: 0.6624 - val_loss: 0.8156 - val_accuracy: 0.6940 - lr: 0.0010 - 47s/epoch - 115ms/step
# Epoch 3/200
# 413/413 - 47s - loss: 0.7664 - accuracy: 0.7010 - val_loss: 0.7458 - val_accuracy: 0.7032 - lr: 0.0010 - 47s/epoch - 113ms/step
# Epoch 4/200
# 413/413 - 60s - loss: 0.7330 - accuracy: 0.7071 - val_loss: 0.7279 - val_accuracy: 0.7081 - lr: 0.0010 - 60s/epoch - 146ms/step
# Epoch 5/200
# 413/413 - 68s - loss: 0.7257 - accuracy: 0.7087 - val_loss: 0.7289 - val_accuracy: 0.7070 - lr: 0.0010 - 68s/epoch - 165ms/step
# Epoch 6/200
# 413/413 - 86s - loss: 0.7225 - accuracy: 0.7095 - val_loss: 0.7229 - val_accuracy: 0.7099 - lr: 0.0010 - 86s/epoch - 208ms/step
# Epoch 7/200
# 413/413 - 65s - loss: 0.7214 - accuracy: 0.7098 - val_loss: 0.7199 - val_accuracy: 0.7115 - lr: 0.0010 - 65s/epoch - 158ms/step
# Epoch 8/200
# 413/413 - 80s - loss: 0.7203 - accuracy: 0.7101 - val_loss: 0.7199 - val_accuracy: 0.7117 - lr: 0.0010 - 80s/epoch - 195ms/step
# Epoch 9/200
# 413/413 - 78s - loss: 0.7197 - accuracy: 0.7101 - val_loss: 0.7189 - val_accuracy: 0.7115 - lr: 0.0010 - 78s/epoch - 188ms/step
# Epoch 10/200
# 413/413 - 58s - loss: 0.7189 - accuracy: 0.7105 - val_loss: 0.7181 - val_accuracy: 0.7116 - lr: 0.0010 - 58s/epoch - 140ms/step
# Epoch 11/200
# 413/413 - 55s - loss: 0.7189 - accuracy: 0.7104 - val_loss: 0.7238 - val_accuracy: 0.7092 - lr: 0.0010 - 55s/epoch - 134ms/step
# Epoch 12/200
# 413/413 - 48s - loss: 0.7188 - accuracy: 0.7104 - val_loss: 0.7197 - val_accuracy: 0.7102 - lr: 0.0010 - 48s/epoch - 115ms/step
# Epoch 13/200
# 413/413 - 47s - loss: 0.7185 - accuracy: 0.7104 - val_loss: 0.7190 - val_accuracy: 0.7108 - lr: 0.0010 - 47s/epoch - 115ms/step
# Epoch 14/200
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 413/413 - 52s - loss: 0.7180 - accuracy: 0.7107 - val_loss: 0.7192 - val_accuracy: 0.7114 - lr: 0.0010 - 52s/epoch - 125ms/step
# Epoch 15/200
# 413/413 - 62s - loss: 0.7165 - accuracy: 0.7112 - val_loss: 0.7169 - val_accuracy: 0.7119 - lr: 5.0000e-04 - 62s/epoch - 149ms/step
# Epoch 16/200
# 413/413 - 55s - loss: 0.7164 - accuracy: 0.7113 - val_loss: 0.7161 - val_accuracy: 0.7120 - lr: 5.0000e-04 - 55s/epoch - 132ms/step
# Epoch 17/200
# 413/413 - 67s - loss: 0.7164 - accuracy: 0.7113 - val_loss: 0.7163 - val_accuracy: 0.7123 - lr: 5.0000e-04 - 67s/epoch - 163ms/step
# Epoch 18/200
# 413/413 - 59s - loss: 0.7164 - accuracy: 0.7113 - val_loss: 0.7163 - val_accuracy: 0.7118 - lr: 5.0000e-04 - 59s/epoch - 143ms/step
# Epoch 19/200
# 413/413 - 59s - loss: 0.7161 - accuracy: 0.7114 - val_loss: 0.7157 - val_accuracy: 0.7120 - lr: 5.0000e-04 - 59s/epoch - 142ms/step
# Epoch 20/200
# 413/413 - 59s - loss: 0.7159 - accuracy: 0.7114 - val_loss: 0.7164 - val_accuracy: 0.7120 - lr: 5.0000e-04 - 59s/epoch - 142ms/step
# Epoch 21/200
# 413/413 - 59s - loss: 0.7159 - accuracy: 0.7114 - val_loss: 0.7178 - val_accuracy: 0.7117 - lr: 5.0000e-04 - 59s/epoch - 144ms/step
# Epoch 22/200
# 413/413 - 59s - loss: 0.7157 - accuracy: 0.7113 - val_loss: 0.7173 - val_accuracy: 0.7121 - lr: 5.0000e-04 - 59s/epoch - 143ms/step
# Epoch 23/200
# 413/413 - 59s - loss: 0.7153 - accuracy: 0.7116 - val_loss: 0.7153 - val_accuracy: 0.7120 - lr: 5.0000e-04 - 59s/epoch - 142ms/step
# Epoch 24/200
# 413/413 - 59s - loss: 0.7152 - accuracy: 0.7116 - val_loss: 0.7153 - val_accuracy: 0.7122 - lr: 5.0000e-04 - 59s/epoch - 143ms/step
# Epoch 25/200
# 413/413 - 59s - loss: 0.7152 - accuracy: 0.7114 - val_loss: 0.7166 - val_accuracy: 0.7113 - lr: 5.0000e-04 - 59s/epoch - 143ms/step
# Epoch 26/200
# 413/413 - 59s - loss: 0.7149 - accuracy: 0.7116 - val_loss: 0.7150 - val_accuracy: 0.7124 - lr: 5.0000e-04 - 59s/epoch - 143ms/step
# Epoch 27/200
# 413/413 - 59s - loss: 0.7147 - accuracy: 0.7116 - val_loss: 0.7147 - val_accuracy: 0.7121 - lr: 5.0000e-04 - 59s/epoch - 143ms/step
# Epoch 28/200
# 413/413 - 59s - loss: 0.7146 - accuracy: 0.7116 - val_loss: 0.7145 - val_accuracy: 0.7122 - lr: 5.0000e-04 - 59s/epoch - 143ms/step
# Epoch 29/200
# 413/413 - 59s - loss: 0.7145 - accuracy: 0.7118 - val_loss: 0.7149 - val_accuracy: 0.7122 - lr: 5.0000e-04 - 59s/epoch - 142ms/step
# Epoch 30/200
# 413/413 - 59s - loss: 0.7144 - accuracy: 0.7118 - val_loss: 0.7139 - val_accuracy: 0.7126 - lr: 5.0000e-04 - 59s/epoch - 143ms/step
# Epoch 31/200
# 413/413 - 59s - loss: 0.7142 - accuracy: 0.7118 - val_loss: 0.7141 - val_accuracy: 0.7126 - lr: 5.0000e-04 - 59s/epoch - 142ms/step
# Epoch 32/200
# 413/413 - 59s - loss: 0.7143 - accuracy: 0.7118 - val_loss: 0.7141 - val_accuracy: 0.7126 - lr: 5.0000e-04 - 59s/epoch - 143ms/step
# Epoch 33/200
# 413/413 - 49s - loss: 0.7141 - accuracy: 0.7118 - val_loss: 0.7137 - val_accuracy: 0.7125 - lr: 5.0000e-04 - 49s/epoch - 118ms/step
# Epoch 34/200
# 413/413 - 47s - loss: 0.7141 - accuracy: 0.7118 - val_loss: 0.7141 - val_accuracy: 0.7124 - lr: 5.0000e-04 - 47s/epoch - 113ms/step
# Epoch 35/200
# 413/413 - 47s - loss: 0.7141 - accuracy: 0.7116 - val_loss: 0.7139 - val_accuracy: 0.7123 - lr: 5.0000e-04 - 47s/epoch - 113ms/step
# Epoch 36/200
# 413/413 - 47s - loss: 0.7140 - accuracy: 0.7118 - val_loss: 0.7159 - val_accuracy: 0.7116 - lr: 5.0000e-04 - 47s/epoch - 114ms/step
# Epoch 37/200
# 413/413 - 47s - loss: 0.7139 - accuracy: 0.7120 - val_loss: 0.7134 - val_accuracy: 0.7125 - lr: 5.0000e-04 - 47s/epoch - 113ms/step
# Epoch 38/200
# 413/413 - 47s - loss: 0.7138 - accuracy: 0.7119 - val_loss: 0.7153 - val_accuracy: 0.7118 - lr: 5.0000e-04 - 47s/epoch - 114ms/step
# Epoch 39/200
# 413/413 - 47s - loss: 0.7138 - accuracy: 0.7118 - val_loss: 0.7139 - val_accuracy: 0.7125 - lr: 5.0000e-04 - 47s/epoch - 114ms/step
# Epoch 40/200
# 413/413 - 47s - loss: 0.7138 - accuracy: 0.7119 - val_loss: 0.7143 - val_accuracy: 0.7126 - lr: 5.0000e-04 - 47s/epoch - 113ms/step
# Epoch 41/200
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 413/413 - 47s - loss: 0.7138 - accuracy: 0.7119 - val_loss: 0.7138 - val_accuracy: 0.7126 - lr: 5.0000e-04 - 47s/epoch - 114ms/step
# Epoch 42/200
# 413/413 - 47s - loss: 0.7129 - accuracy: 0.7122 - val_loss: 0.7135 - val_accuracy: 0.7126 - lr: 2.5000e-04 - 47s/epoch - 113ms/step
# Epoch 43/200
# 413/413 - 47s - loss: 0.7130 - accuracy: 0.7123 - val_loss: 0.7132 - val_accuracy: 0.7127 - lr: 2.5000e-04 - 47s/epoch - 113ms/step
# Epoch 44/200
# 413/413 - 47s - loss: 0.7130 - accuracy: 0.7122 - val_loss: 0.7137 - val_accuracy: 0.7127 - lr: 2.5000e-04 - 47s/epoch - 114ms/step
# Epoch 45/200
# 413/413 - 47s - loss: 0.7130 - accuracy: 0.7122 - val_loss: 0.7129 - val_accuracy: 0.7127 - lr: 2.5000e-04 - 47s/epoch - 113ms/step
# Epoch 46/200
# 413/413 - 47s - loss: 0.7130 - accuracy: 0.7122 - val_loss: 0.7131 - val_accuracy: 0.7126 - lr: 2.5000e-04 - 47s/epoch - 114ms/step
# Epoch 47/200
# 413/413 - 47s - loss: 0.7130 - accuracy: 0.7122 - val_loss: 0.7130 - val_accuracy: 0.7128 - lr: 2.5000e-04 - 47s/epoch - 113ms/step
# Epoch 48/200
# 413/413 - 47s - loss: 0.7130 - accuracy: 0.7122 - val_loss: 0.7139 - val_accuracy: 0.7124 - lr: 2.5000e-04 - 47s/epoch - 114ms/step
# Epoch 49/200
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 413/413 - 47s - loss: 0.7129 - accuracy: 0.7122 - val_loss: 0.7132 - val_accuracy: 0.7128 - lr: 2.5000e-04 - 47s/epoch - 114ms/step
# Epoch 50/200
# 413/413 - 47s - loss: 0.7125 - accuracy: 0.7125 - val_loss: 0.7128 - val_accuracy: 0.7128 - lr: 1.2500e-04 - 47s/epoch - 113ms/step
# Epoch 51/200
# 413/413 - 48s - loss: 0.7125 - accuracy: 0.7124 - val_loss: 0.7133 - val_accuracy: 0.7125 - lr: 1.2500e-04 - 48s/epoch - 117ms/step
# Epoch 52/200
# 413/413 - 47s - loss: 0.7125 - accuracy: 0.7124 - val_loss: 0.7129 - val_accuracy: 0.7129 - lr: 1.2500e-04 - 47s/epoch - 113ms/step
# Epoch 53/200
# 413/413 - 47s - loss: 0.7126 - accuracy: 0.7124 - val_loss: 0.7131 - val_accuracy: 0.7127 - lr: 1.2500e-04 - 47s/epoch - 113ms/step
# Epoch 54/200
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 413/413 - 47s - loss: 0.7126 - accuracy: 0.7124 - val_loss: 0.7128 - val_accuracy: 0.7129 - lr: 1.2500e-04 - 47s/epoch - 114ms/step
# Epoch 55/200
# 413/413 - 47s - loss: 0.7123 - accuracy: 0.7125 - val_loss: 0.7128 - val_accuracy: 0.7128 - lr: 6.2500e-05 - 47s/epoch - 113ms/step
# Epoch 56/200
# 413/413 - 47s - loss: 0.7123 - accuracy: 0.7125 - val_loss: 0.7127 - val_accuracy: 0.7129 - lr: 6.2500e-05 - 47s/epoch - 113ms/step
# Epoch 57/200
# 413/413 - 55s - loss: 0.7122 - accuracy: 0.7125 - val_loss: 0.7127 - val_accuracy: 0.7127 - lr: 6.2500e-05 - 55s/epoch - 134ms/step
# Epoch 58/200
# 413/413 - 59s - loss: 0.7123 - accuracy: 0.7125 - val_loss: 0.7126 - val_accuracy: 0.7128 - lr: 6.2500e-05 - 59s/epoch - 143ms/step
# Epoch 59/200
# 413/413 - 59s - loss: 0.7123 - accuracy: 0.7125 - val_loss: 0.7127 - val_accuracy: 0.7129 - lr: 6.2500e-05 - 59s/epoch - 143ms/step
# Epoch 60/200
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 413/413 - 59s - loss: 0.7122 - accuracy: 0.7125 - val_loss: 0.7126 - val_accuracy: 0.7128 - lr: 6.2500e-05 - 59s/epoch - 143ms/step
# Epoch 61/200
# 413/413 - 59s - loss: 0.7121 - accuracy: 0.7126 - val_loss: 0.7126 - val_accuracy: 0.7128 - lr: 3.1250e-05 - 59s/epoch - 143ms/step
# Epoch 62/200
# 413/413 - 59s - loss: 0.7121 - accuracy: 0.7126 - val_loss: 0.7126 - val_accuracy: 0.7128 - lr: 3.1250e-05 - 59s/epoch - 143ms/step
# Epoch 63/200
# 413/413 - 59s - loss: 0.7121 - accuracy: 0.7126 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 3.1250e-05 - 59s/epoch - 142ms/step
# Epoch 64/200
# 413/413 - 59s - loss: 0.7121 - accuracy: 0.7126 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 3.1250e-05 - 59s/epoch - 143ms/step
# Epoch 65/200
# 413/413 - 59s - loss: 0.7121 - accuracy: 0.7126 - val_loss: 0.7126 - val_accuracy: 0.7129 - lr: 3.1250e-05 - 59s/epoch - 143ms/step
# Epoch 66/200
# 413/413 - 59s - loss: 0.7121 - accuracy: 0.7126 - val_loss: 0.7126 - val_accuracy: 0.7128 - lr: 3.1250e-05 - 59s/epoch - 142ms/step
# Epoch 67/200
#
# Epoch 67: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 413/413 - 59s - loss: 0.7121 - accuracy: 0.7126 - val_loss: 0.7125 - val_accuracy: 0.7128 - lr: 3.1250e-05 - 59s/epoch - 143ms/step
# Epoch 68/200
# 413/413 - 59s - loss: 0.7121 - accuracy: 0.7126 - val_loss: 0.7125 - val_accuracy: 0.7128 - lr: 1.5625e-05 - 59s/epoch - 144ms/step
# Epoch 69/200
# 413/413 - 59s - loss: 0.7121 - accuracy: 0.7126 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 1.5625e-05 - 59s/epoch - 144ms/step
# Epoch 70/200
# 413/413 - 59s - loss: 0.7121 - accuracy: 0.7126 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 1.5625e-05 - 59s/epoch - 143ms/step
# Epoch 71/200
#
# Epoch 71: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 413/413 - 59s - loss: 0.7120 - accuracy: 0.7126 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 1.5625e-05 - 59s/epoch - 142ms/step
# Epoch 72/200
# 413/413 - 58s - loss: 0.7120 - accuracy: 0.7126 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 7.8125e-06 - 58s/epoch - 140ms/step
# Epoch 73/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7126 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 7.8125e-06 - 47s/epoch - 114ms/step
# Epoch 74/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7126 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 7.8125e-06 - 47s/epoch - 113ms/step
# Epoch 75/200
#
# Epoch 75: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7126 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 7.8125e-06 - 47s/epoch - 114ms/step
# Epoch 76/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7127 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 3.9063e-06 - 47s/epoch - 113ms/step
# Epoch 77/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7126 - val_loss: 0.7125 - val_accuracy: 0.7128 - lr: 3.9063e-06 - 47s/epoch - 113ms/step
# Epoch 78/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7127 - val_loss: 0.7125 - val_accuracy: 0.7128 - lr: 3.9063e-06 - 47s/epoch - 114ms/step
# Epoch 79/200
#
# Epoch 79: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7126 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 3.9063e-06 - 47s/epoch - 113ms/step
# Epoch 80/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7126 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 1.9531e-06 - 47s/epoch - 114ms/step
# Epoch 81/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7127 - val_loss: 0.7125 - val_accuracy: 0.7128 - lr: 1.9531e-06 - 47s/epoch - 113ms/step
# Epoch 82/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7126 - val_loss: 0.7125 - val_accuracy: 0.7128 - lr: 1.9531e-06 - 47s/epoch - 114ms/step
# Epoch 83/200
#
# Epoch 83: ReduceLROnPlateau reducing learning rate to 1e-06.
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7126 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 1.9531e-06 - 47s/epoch - 113ms/step
# Epoch 84/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7127 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 1.0000e-06 - 47s/epoch - 113ms/step
# Epoch 85/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7127 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 1.0000e-06 - 47s/epoch - 114ms/step
# Epoch 86/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7127 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 1.0000e-06 - 47s/epoch - 113ms/step
# Epoch 87/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7127 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 1.0000e-06 - 47s/epoch - 113ms/step
# Epoch 88/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7127 - val_loss: 0.7125 - val_accuracy: 0.7128 - lr: 1.0000e-06 - 47s/epoch - 114ms/step
# Epoch 89/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7126 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 1.0000e-06 - 47s/epoch - 113ms/step
# Epoch 90/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7127 - val_loss: 0.7125 - val_accuracy: 0.7128 - lr: 1.0000e-06 - 47s/epoch - 114ms/step
# Epoch 91/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7127 - val_loss: 0.7125 - val_accuracy: 0.7128 - lr: 1.0000e-06 - 47s/epoch - 114ms/step
# Epoch 92/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7127 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 1.0000e-06 - 47s/epoch - 114ms/step
# Epoch 93/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7127 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 1.0000e-06 - 47s/epoch - 114ms/step
# Epoch 94/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7127 - val_loss: 0.7125 - val_accuracy: 0.7128 - lr: 1.0000e-06 - 47s/epoch - 113ms/step
# Epoch 95/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7127 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 1.0000e-06 - 47s/epoch - 114ms/step
# Epoch 96/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7127 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 1.0000e-06 - 47s/epoch - 113ms/step
# Epoch 97/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7126 - val_loss: 0.7125 - val_accuracy: 0.7128 - lr: 1.0000e-06 - 47s/epoch - 113ms/step
# Epoch 98/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7127 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 1.0000e-06 - 47s/epoch - 114ms/step
# Epoch 99/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7126 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 1.0000e-06 - 47s/epoch - 113ms/step
# Epoch 100/200
# 413/413 - 47s - loss: 0.7120 - accuracy: 0.7127 - val_loss: 0.7125 - val_accuracy: 0.7129 - lr: 1.0000e-06 - 47s/epoch - 114ms/step

# %%
#Plot the loss over the number of epochs
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
#Plot the accuracy over the number of epochs
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
model.save('../models/model_ann_whole.h5')
# Out:
# /home/pipc06/.local/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
